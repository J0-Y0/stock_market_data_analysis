# %% [markdown]
# ## Correlation between news and stock movement

# %%
import os

os.chdir("..")  # set the working directory one level up
from scripts.financial_analyzer import FinancialAnalyzer
from scripts.news_analyzer import NewsAnalyzer

f_analyzer = FinancialAnalyzer()
n_analyzer = NewsAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...

# %% [markdown]
# ### load all stock data ,and add `ticker` column

# %%
tickers = ["AAPL", "AMZN", "GOOG", "META", "MSFT", "NVDA", "TSLA"]
stock_data = f_analyzer.load_datas(tickers)
stock_data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-12    0.128348    0.128906    0.128348    0.128348    0.098943
# 1980-12-15    0.122210    0.122210    0.121652    0.121652    0.093781
# 1980-12-16    0.113281    0.113281    0.112723    0.112723    0.086898
# 1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089049
# 1980-12-18    0.118862    0.119420    0.118862    0.118862    0.091630
# ...                ...         ...         ...         ...         ...
# 2024-07-24  225.419998  225.990005  214.710007  215.990005  215.990005
# 2024-07-25  216.800003  226.000000  216.229996  220.250000  220.250000
# 2024-07-26  221.190002  222.279999  215.330002  219.800003  219.800003
# 2024-07-29  224.899994  234.270004  224.699997  232.100006  232.100006
# 2024-07-30  232.250000  232.410004  220.000000  222.619995  222.619995
#
#                Volume  Dividends  Stock Splits Stock
# Date
# 1980-12-12  469033600        0.0           0.0  AAPL
# 1980-12-15  175884800        0.0           0.0  AAPL
# 1980-12-16  105728000        0.0           0.0  AAPL
# 1980-12-17   86441600        0.0           0.0  AAPL
# 1980-12-18   73449600        0.0           0.0  AAPL
# ...               ...        ...           ...   ...
# 2024-07-24  167942900        0.0           0.0  TSLA
# 2024-07-25  100636500        0.0           0.0  TSLA
# 2024-07-26   94604100        0.0           0.0  TSLA
# 2024-07-29  129201800        0.0           0.0  TSLA
# 2024-07-30  100560300        0.0           0.0  TSLA
#
# [45428 rows x 9 columns]

# %% [markdown]
# ### Load normalized `news data`

# %%
news_data = f_analyzer.load_data("datasets/raw_analyst_ratings.csv", isPath=True)

news_data.drop(columns="Unnamed: 0", errors="ignore", inplace=True)
news_data.head()
# Out:
#                                                      headline  \
# Date
# 2020-06-05            Stocks That Hit 52-Week Highs On Friday
# 2020-06-03         Stocks That Hit 52-Week Highs On Wednesday
# 2020-05-26                      71 Biggest Movers From Friday
# 2020-05-22       46 Stocks Moving In Friday's Mid-Day Session
# 2020-05-22  B of A Securities Maintains Neutral on Agilent...
#
#                                                           url  \
# Date
# 2020-06-05  https://www.benzinga.com/news/20/06/16190091/s...
# 2020-06-03  https://www.benzinga.com/news/20/06/16170189/s...
# 2020-05-26  https://www.benzinga.com/news/20/05/16103463/7...
# 2020-05-22  https://www.benzinga.com/news/20/05/16095921/4...
# 2020-05-22  https://www.benzinga.com/news/20/05/16095304/b...
#
#                     publisher Stock
# Date
# 2020-06-05  Benzinga Insights     A
# 2020-06-03  Benzinga Insights     A
# 2020-05-26         Lisa Levin     A
# 2020-05-22         Lisa Levin     A
# 2020-05-22         Vick Meyer     A

# %% [markdown]
# ## `Descriptive` statistics

# %%
news_data.describe()
# Out:
#                        headline  \
# count                   1407328
# unique                   845770
# top     Benzinga's Top Upgrades
# freq                       5449
#
#                                                       url      publisher  \
# count                                             1407328        1407328
# unique                                             883429           1034
# top     https://www.benzinga.com/news/20/03/15538835/s...  Paul Quintaro
# freq                                                 1704         228373
#
#           Stock
# count   1407328
# unique     6204
# top         MRK
# freq       3333

# %% [markdown]
# ## `Sentiment`: Text analysis

# %%
news_data = n_analyzer.sentiment(news_data)
news_data.head()
# Out:
#                                                      headline  \
# Date
# 2020-06-05            Stocks That Hit 52-Week Highs On Friday
# 2020-06-03         Stocks That Hit 52-Week Highs On Wednesday
# 2020-05-26                      71 Biggest Movers From Friday
# 2020-05-22       46 Stocks Moving In Friday's Mid-Day Session
# 2020-05-22  B of A Securities Maintains Neutral on Agilent...
#
#                                                           url  \
# Date
# 2020-06-05  https://www.benzinga.com/news/20/06/16190091/s...
# 2020-06-03  https://www.benzinga.com/news/20/06/16170189/s...
# 2020-05-26  https://www.benzinga.com/news/20/05/16103463/7...
# 2020-05-22  https://www.benzinga.com/news/20/05/16095921/4...
# 2020-05-22  https://www.benzinga.com/news/20/05/16095304/b...
#
#                     publisher Stock  \
# Date
# 2020-06-05  Benzinga Insights     A
# 2020-06-03  Benzinga Insights     A
# 2020-05-26         Lisa Levin     A
# 2020-05-22         Lisa Levin     A
# 2020-05-22         Vick Meyer     A
#
#                                              Sentiment Scores Sentiment
# Date
# 2020-06-05  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...   neutral
# 2020-06-03  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...   neutral
# 2020-05-26  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...   neutral
# 2020-05-22  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...   neutral
# 2020-05-22  {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'comp...  positive

# %% [markdown]
# ### Daily Stock `Returns`:

# %%
df["Daily Return"] = df["Close"].pct_change() * 100
