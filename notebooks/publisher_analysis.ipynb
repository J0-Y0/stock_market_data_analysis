# %% [markdown]
# ### Publisher_analysis
# Load and Prepare Data

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("../datasets/raw_analyst_ratings.csv")

# Display the first few rows to understand the structure
print(df.head())
# Out:
#    Unnamed: 0                                           headline  \
# 0           0            Stocks That Hit 52-Week Highs On Friday
# 1           1         Stocks That Hit 52-Week Highs On Wednesday
# 2           2                      71 Biggest Movers From Friday
# 3           3       46 Stocks Moving In Friday's Mid-Day Session
# 4           4  B of A Securities Maintains Neutral on Agilent...
#
#                                                  url          publisher  \
# 0  https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1  https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# 2  https://www.benzinga.com/news/20/05/16103463/7...         Lisa Levin
# 3  https://www.benzinga.com/news/20/05/16095921/4...         Lisa Levin
# 4  https://www.benzinga.com/news/20/05/16095304/b...         Vick Meyer
#
#                         date stock
# 0  2020-06-05 10:30:54-04:00     A
# 1  2020-06-03 10:45:20-04:00     A
# 2  2020-05-26 04:30:07-04:00     A
# 3  2020-05-22 12:45:06-04:00     A
# 4  2020-05-22 11:38:59-04:00     A

# %% [markdown]
# Count Articles per Publisher

# %%
# Count the number of articles per publisher
publisher_counts = df["publisher"].value_counts()

# Display the top publishers
print(publisher_counts)
# Out:
# publisher
# Paul Quintaro                      228373
# Lisa Levin                         186979
# Benzinga Newsdesk                  150484
# Charles Gross                       96732
# Monica Gerson                       82380
#                                     ...
# Shazir Mucklai - Imperium Group         1
# Laura Jennings                          1
# Eric Martin                             1
# Jose Rodrigo                            1
# Jeremie Capron                          1
# Name: count, Length: 1034, dtype: int64

# %% [markdown]
# Analyze the Type of News Reported by Each Publisher

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np

# Load dataset
df = pd.read_csv("../datasets/raw_analyst_ratings.csv")

# Preprocess text: Tokenize and remove stopwords
def preprocess_text(text):
    return " ".join([word.lower() for word in text.split() if word.isalnum()])

# Apply preprocessing
df["clean_headline"] = df["headline"].apply(preprocess_text)

# Vectorize the headlines
vectorizer = CountVectorizer(stop_words="english")
X = vectorizer.fit_transform(df["clean_headline"])

# Get feature names
feature_names = vectorizer.get_feature_names_out()

# Convert sparse matrix to DataFrame (if necessary, e.g., for small datasets)
# features_df = pd.DataFrame(X.toarray(), columns=feature_names, index=df.index)

# Group by publisher and sum the counts of each word
def get_word_counts(publisher_group):
    # Extract the rows corresponding to this publisher
    word_counts = np.asarray(X[publisher_group.index].sum(axis=0)).flatten()
    return pd.Series(word_counts, index=feature_names)

publisher_word_counts = df.groupby("publisher").apply(get_word_counts).fillna(0)

# Display the top words for each publisher
for publisher in publisher_word_counts.index:
    word_counts = publisher_word_counts.loc[publisher]
    top_words = word_counts.sort_values(ascending=False).head(10)
    print(f"Top words for {publisher}:")
    print(top_words)
    print()
# Out:
# C:\Users\SQL\AppData\Local\Temp\2\ipykernel_9020\1246782493.py:31: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   publisher_word_counts = df.groupby("publisher").apply(get_word_counts).fillna(0)
# Top words for 47ertrends:
# trends      18
# february    18
# stock       18
# market      18
# 2012        18
# 000          0
# optune       0
# opxa         0
# opw          0
# opvido       0
# Name: 47ertrends, dtype: int64
#
# Top words for AARP:
# ways          7
# businesses    5
# right         5
# help          5
# small         5
# emergency     5
# worker        2
# home          2
# money         2
# earn          2
# Name: AARP, dtype: int64
#
# Top words for ABNNewswire:
# limited       8
# nl            4
# resources     3
# celamin       3
# million       3
# update        3
# companies     3
# projects      3
# activities    3
# holdings      3
# Name: ABNNewswire, dtype: int64
#
# Top words for Aakin:
# report      2
# airport     2
# security    2
# sony        1
# dslr        1
# live        1
# ups         1
# ante        1
# latest      1
# audiovox    1
# Name: Aakin, dtype: int64
#
# Top words for Aaron Jackson.Ed:
# week           15
# things          9
# read            9
# reads           6
# best            5
# financial       4
# blogosphere     4
# stocks          1
# profit          1
# momentum        1
# Name: Aaron Jackson.Ed, dtype: int64
#
# Top words for Aaron Levitt:
# play         15
# emerging     13
# growth       13
# market       13
# big          12
# dividends    11
# bonds        11
# world        11
# good         11
# investing    11
# Name: Aaron Levitt, dtype: int64
#
# Top words for Abe Raymond:
# summary      546
# market       519
# 2011         463
# vs           274
# november     203
# est          156
# afternoon    154
# eps          150
# revenues     129
# december     125
# Name: Abe Raymond, dtype: int64
#
# Top words for Abhi Rao:
# market       31
# 2011         26
# december     26
# summary      26
# short        10
# companies     9
# afternoon     9
# gas           8
# destroy       7
# going         7
# Name: Abhi Rao, dtype: int64
#
# Top words for Abigail Field:
# congress      8
# fhfa          7
# goldman       7
# big           6
# tax           6
# break         5
# prepares      5
# ge            5
# rbs           4
# settlement    4
# Name: Abigail Field, dtype: int64
#
# Top words for Above Average Odds:
# investment        17
# corporation        4
# classic            3
# team               2
# gold               2
# energold           2
# penn               2
# management         2
# infrastructure     2
# turnaround         2
# Name: Above Average Odds, dtype: int64
#
# Top words for Accointing:
# trends            2
# cryptocurrency    2
# 2020              2
# biggest           2
# orapharma         0
# optum             0
# opw               0
# opvido            0
# opus              0
# opulan            0
# Name: Accointing, dtype: int64
#
# Top words for Activist Stocks:
# hedge      13
# rush       10
# funds      10
# energy     10
# carl        6
# icahn       6
# ceo         6
# new         4
# managed     3
# eye         3
# Name: Activist Stocks, dtype: int64
#
# Top words for Adam Gefvert:
# comparison    2
# channels      2
# available     2
# channel       2
# value         1
# loco          1
# pollo         1
# comparing     1
# share         1
# chipotle      1
# Name: Adam Gefvert, dtype: int64
#
# Top words for Adam Parker:
# oppenheimer    8
# gaming         8
# lodging        7
# review         7
# weekly         7
# releases       7
# comments       5
# summary        5
# meeting        5
# morning        5
# Name: Adam Parker, dtype: int64
#
# Top words for Adam Sarhan:
# just           4
# market         4
# does           4
# consecutive    4
# fell           4
# benefit        4
# deserve        4
# stocks         4
# opxa           0
# opw            0
# Name: Adam Sarhan, dtype: int64
#
# Top words for Adam Weiner:
# begins      1
# cleaning    1
# spring      1
# aol         1
# 000         0
# opuchase    0
# ora         0
# or3o        0
# opxa        0
# opw         0
# Name: Adam Weiner, dtype: int64
#
# Top words for Alan Brochstein:
# marijuana     5
# stocks        4
# pot           2
# year          2
# pay           2
# fared         2
# sector        2
# correction    2
# investors     1
# vigilant      1
# Name: Alan Brochstein, dtype: int64
#
# Top words for Alex Biles:
# business         94
# today            92
# ceos             80
# 100              71
# 20               26
# stocks           26
# 2013             24
# america          23
# ecommerce        19
# environmental    18
# Name: Alex Biles, dtype: int64
#
# Top words for Alex Cho:
# analysts    8
# reports     8
# guidance    8
# earnings    7
# moves       6
# dollar      6
# bank        6
# higher      6
# beats       5
# deutsche    4
# Name: Alex Cho, dtype: int64
#
# Top words for Alex Furno:
# midday       278
# stocks       237
# gainers      228
# losers       226
# following    206
# earnings     175
# morning      159
# december     145
# movers       130
# november     122
# Name: Alex Furno, dtype: int64
#
# Top words for Alex Ivanovs:
# data         1
# twitter      1
# hacked       1
# machine      1
# getting      1
# pandora      1
# tips         1
# learning     1
# using        1
# interpret    1
# Name: Alex Ivanovs, dtype: int64
#
# Top words for Alex Oleinic:
# cannabis    45
# cbd         32
# products    16
# deal        14
# growth      14
# stocks      11
# joins       10
# stores       9
# gw           8
# gainers      7
# Name: Alex Oleinic, dtype: int64
#
# Top words for Alex Roslin:
# disaster    1
# 500         1
# finds       1
# smart       1
# money       1
# opuchase    0
# ora         0
# or3o        0
# opxa        0
# opw         0
# Name: Alex Roslin, dtype: int64
#
# Top words for Alex Schiff:
# value        2
# sheds        1
# housing      1
# care         1
# seniors      1
# real         1
# crisis       1
# means        1
# financial    1
# light        1
# Name: Alex Schiff, dtype: int64
#
# Top words for Alex Shadunsky:
# bayer       3
# buying      3
# market      3
# remains     3
# finally     3
# hesitant    3
# shops       2
# supply      2
# amazon      2
# book        2
# Name: Alex Shadunsky, dtype: int64
#
# Top words for Alex Shek:
# earnings     39
# companies    16
# afternoon    15
# report       11
# q1           10
# doing        10
# bell         10
# natural       9
# rises         9
# general       8
# Name: Alex Shek, dtype: int64
#
# Top words for Alexander Voigt:
# week        1
# watch       1
# float       1
# low         1
# stocks      1
# optum360    0
# opxa        0
# opw         0
# opvido      0
# opus        0
# Name: Alexander Voigt, dtype: int64
#
# Top words for Alexis Raskin:
# online     9
# credit     8
# banks      7
# banking    7
# best       6
# ways       5
# bank       5
# fees       5
# card       4
# rewards    4
# Name: Alexis Raskin, dtype: int64
#
# Top words for Alfidi Capital:
# 2011          5
# fall          4
# news          4
# rail          3
# starting      3
# times         3
# tough         3
# williams      2
# mighty        2
# disastrous    2
# Name: Alfidi Capital, dtype: int64
#
# Top words for Alfredlittle:
# happened      1
# hangs         1
# silvercorp    1
# lorne         1
# really        1
# investors     1
# optus         0
# or3o          0
# opxa          0
# opw           0
# Name: Alfredlittle, dtype: int64
#
# Top words for Ali Berri:
# shares      104
# markets     102
# earnings    101
# 2014         85
# profit       57
# morning      53
# upbeat       52
# stocks       51
# july         48
# reports      45
# Name: Ali Berri, dtype: int64
#
# Top words for Ali Hakim:
# auto         18
# earnings     15
# street       13
# investors    12
# deal         11
# report       10
# market        9
# outlook       8
# does          8
# solar         7
# Name: Ali Hakim, dtype: int64
#
# Top words for All Options On The Table with John Salters Jr.:
# corp       2
# news       2
# 000        0
# opulan     0
# oracale    0
# ora        0
# or3o       0
# opxa       0
# opw        0
# opvido     0
# Name: All Options On The Table with John Salters Jr., dtype: int64
#
# Top words for Allan Farley:
# fintech      1
# expansion    1
# drive        1
# cto          1
# major        1
# new          1
# oanda        1
# optr         0
# opulan       0
# oracale      0
# Name: Allan Farley, dtype: int64
#
# Top words for Allie Wickman:
# vs           5271
# reports      3227
# eps          3068
# est          2949
# revenues     2623
# announces    2221
# q2           1432
# financial    1388
# news         1353
# summary      1289
# Name: Allie Wickman, dtype: int64
#
# Top words for Allyson Brooks:
# home        6
# 2018        4
# minimize    3
# review      3
# hacks       3
# brokers     3
# fees        3
# abroad      3
# online      3
# trip        3
# Name: Allyson Brooks, dtype: int64
#
# Top words for Alpha Works:
# secrets     1
# hongmeng    1
# android     1
# beating     1
# anchored    1
# optus       0
# or3o        0
# opxa        0
# opw         0
# opvido      0
# Name: Alpha Works, dtype: int64
#
# Top words for Alpha7Trading:
# auto             2
# media            1
# time             1
# look             1
# sales            1
# strong           1
# outperform       1
# stab             1
# discretionary    1
# volatility       1
# Name: Alpha7Trading, dtype: int64
#
# Top words for AlphaClone:
# 101           7
# cloning       7
# alphaclone    2
# 000           0
# optune        0
# or3o          0
# opxa          0
# opw           0
# opvido        0
# opus          0
# Name: AlphaClone, dtype: int64
#
# Top words for Amit Nag:
# china       7
# google      6
# capital     5
# plans       5
# vehicles    4
# hong        4
# tesla       4
# kong        4
# launch      4
# model       4
# Name: Amit Nag, dtype: int64
#
# Top words for Amy Weingarden:
# shares        48
# earnings      46
# credit        45
# investment    44
# ideas         42
# place         42
# stocks        39
# week          31
# following     30
# season        26
# Name: Amy Weingarden, dtype: int64
#
# Top words for Andre Bourque:
# famed        3
# critic       3
# says         3
# beverages    3
# cannabis     2
# industry     2
# learn        2
# opioid       2
# crisis       2
# health       2
# Name: Andre Bourque, dtype: int64
#
# Top words for Andre Gratian:
# market        5
# points        5
# turning       5
# interim       4
# rally         4
# newsletter    3
# july          2
# ahead         2
# directly      2
# reached       1
# Name: Andre Gratian, dtype: int64
#
# Top words for Andrew Aziz:
# going       2
# oracale     0
# or3o        0
# opxa        0
# opw         0
# opvido      0
# opus        0
# opulan      0
# opuchase    0
# optus       0
# Name: Andrew Aziz, dtype: int64
#
# Top words for Andrew Efimoff:
# gainers     64
# 10          58
# earnings    52
# stocks      41
# beats       32
# thursday    31
# reports     30
# shares      27
# misses      27
# says        27
# Name: Andrew Efimoff, dtype: int64
#
# Top words for Andrew Geller:
# away         2
# intel        2
# pivot        2
# tech         2
# unlikely     2
# 5g           2
# apple        2
# says         1
# logistics    1
# review       1
# Name: Andrew Geller, dtype: int64
#
# Top words for Andrew Moran:
# acquires    1
# zipcar      1
# avis        1
# optrex      0
# optricon    0
# oracale     0
# ora         0
# or3o        0
# opxa        0
# opw         0
# Name: Andrew Moran, dtype: int64
#
# Top words for Andrew Rosenbaum:
# like       3
# etfs       3
# popular    2
# bond       2
# grow       2
# agg        2
# index      1
# copper     1
# profit     1
# help       1
# Name: Andrew Rosenbaum, dtype: int64
#
# Top words for Andrew Ward:
# cbd          16
# cannabis     14
# market        7
# says          6
# canopy        5
# growth        5
# kroger        4
# products      4
# 17            4
# introduce     4
# Name: Andrew Ward, dtype: int64
#
# Top words for Andrew Zatlin:
# semiconductor    5
# economy          5
# global           5
# omen             4
# bad              4
# slowdown         4
# watch            3
# earnings         2
# silicon          2
# valley           2
# Name: Andrew Zatlin, dtype: int64
#
# Top words for Andy Brown:
# deal         3
# lingering    3
# questions    3
# optus        0
# ora          0
# or3o         0
# opxa         0
# opw          0
# opvido       0
# opus         0
# Name: Andy Brown, dtype: int64
#
# Top words for Andy Djordjalian:
# investment    8
# management    8
# brazilian     8
# covestor      8
# stocks        8
# invest        8
# 000           0
# optus         0
# or3o          0
# opxa          0
# Name: Andy Djordjalian, dtype: int64
#
# Top words for Andy Pai:
# stocks         28
# undervalued    17
# upside         13
# chuck          10
# portfolio      10
# buffett         7
# regeneron       7
# bought          7
# new             7
# boone           7
# Name: Andy Pai, dtype: int64
#
# Top words for Andy Swan:
# social       24
# data         20
# twitter       8
# saying        8
# honda         7
# companies     7
# set           7
# poised        7
# 10            6
# sentiment     6
# Name: Andy Swan, dtype: int64
#
# Top words for Andy@andyswan.com:
# consumers    5
# breakout     5
# flocking     5
# 000          0
# optune       0
# or3o         0
# opxa         0
# opw          0
# opvido       0
# opus         0
# Name: Andy@andyswan.com, dtype: int64
#
# Top words for Angry Bear:
# guest           4
# greece          3
# irish           2
# high            2
# default         2
# provost         2
# love            2
# shores          2
# unemployment    2
# rich            2
# Name: Angry Bear, dtype: int64
#
# Top words for Ankitha Taranath:
# pepsico       2
# rupee         2
# indian        2
# cola          2
# continues     2
# fall          2
# dollar        2
# trading       2
# recovering    1
# signal        1
# Name: Ankitha Taranath, dtype: int64
#
# Top words for Anna Gerardi:
# pt            66
# raises        53
# morgan        52
# reports       48
# rating        30
# reiterates    30
# goldman       29
# sachs         29
# bank          25
# jefferies     24
# Name: Anna Gerardi, dtype: int64
#
# Top words for Anna Hicks:
# industry     2
# job          2
# hold         2
# fueling      2
# growth       2
# jobs         2
# renewable    2
# future       2
# does         2
# energy       2
# Name: Anna Hicks, dtype: int64
#
# Top words for AnneMarieTrades:
# nov              1
# play             1
# consideration    1
# 000              0
# optune           0
# or3o             0
# opxa             0
# opw              0
# opvido           0
# opus             0
# Name: AnneMarieTrades, dtype: int64
#
# Top words for Annibale Marsili:
# encouraging    2
# data           2
# economy        2
# need           1
# european       1
# spain          1
# british        1
# banks          1
# look           1
# messed         1
# Name: Annibale Marsili, dtype: int64
#
# Top words for Anthony Cibotti:
# presentation    1
# day             1
# await           1
# ubs             1
# share           1
# holders         1
# optune          0
# opw             0
# opvido          0
# opus            0
# Name: Anthony Cibotti, dtype: int64
#
# Top words for Anthony Dadlani:
# markets      2
# triple       1
# went         1
# yesterday    1
# numbers      1
# asian        1
# asia         1
# awful        1
# saw          1
# run          1
# Name: Anthony Dadlani, dtype: int64
#
# Top words for Anthony Sanfilippo:
# downgrades    47
# says          29
# bank          27
# morgan        26
# upgrades      25
# stanley       21
# earnings      20
# target        18
# deutsche      17
# sees          17
# Name: Anthony Sanfilippo, dtype: int64
#
# Top words for Anthony Valeri:
# summer     1
# oil        1
# federal    1
# dollar     1
# 2015       1
# optus      0
# or3o       0
# opxa       0
# opw        0
# opvido     0
# Name: Anthony Valeri, dtype: int64
#
# Top words for Anthony Viola:
# department    7
# holiday       7
# season        7
# kind          7
# stores        7
# discount      7
# bank          5
# america       5
# loved         5
# traders       5
# Name: Anthony Viola, dtype: int64
#
# Top words for AntonRobb:
# healthcare    3
# senate        3
# insurance     2
# windstream    2
# stock         2
# stocks        2
# hits          2
# research      2
# inadequate    2
# passes        2
# Name: AntonRobb, dtype: int64
#
# Top words for António Costa:
# stocks       1083
# watch        1059
# 2013          448
# week          289
# watchlist     280
# ideas         251
# trade         232
# stock         214
# setups        184
# june          162
# Name: António Costa, dtype: int64
#
# Top words for Anupam Varshney:
# investing     2
# companies     2
# tech          2
# blockchain    2
# largest       2
# optune        0
# opw           0
# opvido        0
# opus          0
# opulan        0
# Name: Anupam Varshney, dtype: int64
#
# Top words for Ari Crane:
# bank          27
# initiates     27
# america       20
# upgrades      17
# raises        15
# buy           15
# pt            15
# downgrades    14
# growth        13
# market        12
# Name: Ari Crane, dtype: int64
#
# Top words for Ari Nazir:
# ethereum    1
# tech        1
# poised      1
# optune      0
# or3o        0
# opxa        0
# opw         0
# opvido      0
# opus        0
# opulan      0
# Name: Ari Nazir, dtype: int64
#
# Top words for Armen:
# dollar        49
# euro          25
# british       18
# pound         18
# canadian      16
# australian    16
# higher        14
# rallies       11
# franc         10
# swiss          9
# Name: Armen, dtype: int64
#
# Top words for Arshon Afrakhteh:
# citing        11
# downgrades     9
# raises         6
# pt             6
# buy            4
# goldman        4
# sachs          4
# rating         4
# bank           4
# price          3
# Name: Arshon Afrakhteh, dtype: int64
#
# Top words for Ashley Carter:
# service     1
# hacked      1
# ways        1
# cloud       1
# protect     1
# 000         0
# opuchase    0
# or3o        0
# opxa        0
# opw         0
# Name: Ashley Carter, dtype: int64
#
# Top words for Asif Suria:
# arbitrage    110
# merger       110
# mondays      110
# 2011          89
# 2010          55
# insider       45
# july          33
# weekends      32
# august        27
# september     21
# Name: Asif Suria, dtype: int64
#
# Top words for Aswath Damodaran:
# tech          2
# testing       2
# worse         1
# market        1
# mark          1
# emerging      1
# collapse      1
# investment    1
# price         1
# turmoil       1
# Name: Aswath Damodaran, dtype: int64
#
# Top words for Atish Davda:
# era       3
# dawn      3
# path      1
# ipo       1
# optune    0
# or3o      0
# opxa      0
# opw       0
# opvido    0
# opus      0
# Name: Atish Davda, dtype: int64
#
# Top words for Aurie Maine:
# real       1
# like       1
# buying     1
# creates    1
# stock      1
# rising     1
# risk       1
# price      1
# big        1
# focus      1
# Name: Aurie Maine, dtype: int64
#
# Top words for Austrolib:
# like        1
# trius       1
# cubist      1
# lot         1
# looks       1
# acquired    1
# cempra      1
# right       1
# optus       0
# opxa        0
# Name: Austrolib, dtype: int64
#
# Top words for Avi Gilburt:
# metals           5
# miners           4
# dear             3
# continue         3
# buy              3
# consolidation    2
# reassess         2
# recent           2
# watch            2
# complex          2
# Name: Avi Gilburt, dtype: int64
#
# Top words for Barbara Friedberg:
# risk           2
# investing      1
# secret         1
# retail         1
# little         1
# trend          1
# avoid          1
# traditional    1
# dying          1
# dirty          1
# Name: Barbara Friedberg, dtype: int64
#
# Top words for Barel Karsan:
# value          3
# keryx          2
# product        2
# rearden        2
# update         2
# hamot          2
# eps            2
# development    2
# mailbag        2
# biopharma      2
# Name: Barel Karsan, dtype: int64
#
# Top words for Barry Bazzell:
# netflix    7
# nfc        6
# percent    6
# soars      6
# 130        6
# chip       6
# maker      6
# months     6
# stock      6
# player     5
# Name: Barry Bazzell, dtype: int64
#
# Top words for BehindWallStreet:
# time             4
# stock            4
# buying           3
# trading          3
# investing        2
# stocks           2
# investor         2
# entertainment    2
# johnson          2
# famour           2
# Name: BehindWallStreet, dtype: int64
#
# Top words for Ben Deng:
# morgan       12
# stanley      10
# following     7
# pt            6
# lowers        5
# results       4
# 4q13          3
# upgrades      3
# jp            2
# earnings      2
# Name: Ben Deng, dtype: int64
#
# Top words for Ben Reynolds:
# cardinal      2
# attractive    2
# dividends     2
# rising        2
# make          2
# 000           0
# optune        0
# opxa          0
# opw           0
# opvido        0
# Name: Ben Reynolds, dtype: int64
#
# Top words for Ben Reynolds - SureDividend.com:
# dividend    22
# takes       18
# king        18
# growth       3
# long         2
# hold         2
# run          2
# stocks       2
# yields       1
# reliable     1
# Name: Ben Reynolds - SureDividend.com, dtype: int64
#
# Top words for Beni Hakak:
# chain         3
# integrity     3
# achieving     3
# settlement    3
# gross         3
# optune        0
# opxa          0
# opw           0
# opvido        0
# opus          0
# Name: Beni Hakak, dtype: int64
#
# Top words for Benjamin Lee:
# stocks        1383
# lows          1216
# highs         1208
# watch         1202
# fresh         1193
# week           938
# 52             938
# percentage     624
# losers         624
# gainers        624
# Name: Benjamin Lee, dtype: int64
#
# Top words for Benny Emerling:
# mean        3
# loan        3
# high        3
# record      3
# stocks      3
# market      3
# business    3
# small       3
# dynamic     2
# cities      2
# Name: Benny Emerling, dtype: int64
#
# Top words for Benzinga Cannabis:
# cannabis     19
# industry     11
# explained     8
# charts        8
# blooming      8
# weed          8
# complete      7
# companies     7
# nyse          7
# list          7
# Name: Benzinga Cannabis, dtype: int64
#
# Top words for Benzinga Cannabis Contributors:
# need         2
# cannabis     2
# medicine     1
# future       1
# source       1
# open         1
# promising    1
# 000          0
# optum        0
# opulan       0
# Name: Benzinga Cannabis Contributors, dtype: int64
#
# Top words for Benzinga Events:
# cannabis     4
# benzinga     3
# ai           2
# traders      2
# accern       2
# ceo          2
# leverages    2
# virtual      2
# edge         2
# data         1
# Name: Benzinga Events, dtype: int64
#
# Top words for Benzinga Insights:
# stocks      3119
# session     1560
# hit         1559
# moving      1548
# highs       1186
# earnings     613
# stats        492
# market       492
# minutes      492
# q1           415
# Name: Benzinga Insights, dtype: int64
#
# Top words for Benzinga Newdesk:
# vs          408
# option      391
# earnings    303
# calls       276
# sweep       260
# near        207
# open        171
# close       140
# puts        114
# jul         114
# Name: Benzinga Newdesk, dtype: int64
#
# Top words for Benzinga News Desk:
# market      3406
# minutes      870
# earnings     392
# 2016         224
# march        184
# trump        173
# stocks       161
# big          138
# oil          134
# guess        133
# Name: Benzinga News Desk, dtype: int64
#
# Top words for Benzinga Newsdesk:
# shares       42366
# trading      38800
# stocks       27595
# eps          27300
# sales        26852
# new          21392
# companies    21244
# set          16965
# higher       16856
# lower        16034
# Name: Benzinga Newsdesk, dtype: int64
#
# Top words for Benzinga Pro Newsdesk:
# trading    107
# lower       79
# eps         70
# shares      62
# sales       62
# stocks      51
# higher      45
# energy      39
# q3          39
# company     37
# Name: Benzinga Pro Newsdesk, dtype: int64
#
# Top words for Benzinga Staff:
# reports        4048
# announces      3866
# eps            3362
# quarter        2187
# hits           1488
# results        1437
# dividend       1304
# market         1255
# corporation    1224
# trading        1173
# Name: Benzinga Staff, dtype: int64
#
# Top words for Benzinga Staff 5:
# rating         358
# maintains      235
# buy            219
# reports        177
# update         173
# price          171
# target         159
# stocks         144
# corporation    142
# market         135
# Name: Benzinga Staff 5, dtype: int64
#
# Top words for Benzinga Staff Writer:
# earnings    1889
# revenue     1106
# expect       955
# analysts     808
# expected     636
# rise         539
# higher       521
# quarter      516
# rising       390
# eps          350
# Name: Benzinga Staff Writer, dtype: int64
#
# Top words for Benzinga Staff15:
# stocks      95
# watch       78
# earnings    74
# preview     69
# cramer      58
# gainers     32
# jim         21
# likes       19
# bullish     17
# says        14
# Name: Benzinga Staff15, dtype: int64
#
# Top words for Benzinga  Newsdesk:
# trading      650
# shares       587
# lower        408
# company      354
# higher       281
# eps          174
# reported     170
# versus       135
# announced    129
# companies    120
# Name: Benzinga  Newsdesk, dtype: int64
#
# Top words for BenzingaStaff1:
# announces      119
# results         62
# 2009            51
# new             48
# q3              46
# corporation     42
# financial       40
# reports         37
# shares          27
# target          24
# Name: BenzingaStaff1, dtype: int64
#
# Top words for BenzingaStaff2:
# shares           3
# rise             2
# retractable      1
# gas              1
# fall             1
# acquisition      1
# disappointing    1
# announcing       1
# delta            1
# selection        1
# Name: BenzingaStaff2, dtype: int64
#
# Top words for BenzingaStaff3:
# gainers     471
# losers      382
# roundup     306
# market      254
# upgrades    220
# earnings    208
# stocks      199
# news        198
# new         176
# high        154
# Name: BenzingaStaff3, dtype: int64
#
# Top words for BenzingaStaffB:
# comments     323
# rating       319
# morgan       313
# reports      267
# estimates    162
# target       162
# bank         160
# price        157
# buy          152
# jefferies    152
# Name: BenzingaStaffB, dtype: int64
#
# Top words for BenzingaStaffJ:
# maintains     1130
# pt             845
# buy            721
# morgan         683
# raises         547
# lowers         379
# reiterates     347
# bank           342
# jefferies      341
# piper          276
# Name: BenzingaStaffJ, dtype: int64
#
# Top words for BenzingaStaffK:
# reports      46
# morgan       14
# comments     13
# company      12
# jefferies    12
# bank          9
# deutsche      8
# jp            8
# gabelli       8
# rating        7
# Name: BenzingaStaffK, dtype: int64
#
# Top words for BenzingaStaffL:
# morgan       487
# pt           464
# raises       460
# target       417
# rating       368
# jefferies    339
# maintains    280
# reports      278
# goldman      253
# estimates    247
# Name: BenzingaStaffL, dtype: int64
#
# Top words for BenzingaStaffT:
# pt          329
# vs          326
# reports     254
# est         191
# eps         183
# q2          166
# morgan      152
# raises      149
# revenues    142
# bank        119
# Name: BenzingaStaffT, dtype: int64
#
# Top words for Benzinga_Newsdesk:
# target        8242
# price         7962
# maintains     4108
# raises        2913
# buy           2885
# lowers        2833
# announces     2728
# downgrades    2304
# initiates     1939
# eps           1904
# Name: Benzinga_Newsdesk, dtype: int64
#
# Top words for Benzinga Newsdesk:
# trading      3598
# shares       3571
# companies    3509
# higher       2253
# amid         1977
# following    1764
# economic     1755
# optimism     1427
# lower        1291
# reopening    1259
# Name: Benzinga Newsdesk, dtype: int64
#
# Top words for Bernard Clay:
# masses         2
# feds           2
# frustrating    2
# getting        1
# levels         1
# bullishness    1
# extreme        1
# opulan         0
# oracale        0
# ora            0
# Name: Bernard Clay, dtype: int64
#
# Top words for Bill Baruch:
# watch        6
# levels       5
# 2018         5
# technical    5
# february     3
# march        2
# today        1
# market       1
# signals      1
# trade        1
# Name: Bill Baruch, dtype: int64
#
# Top words for Bill Haddad:
# 2018          130
# analyst        99
# calls          98
# april          77
# vetr           72
# crowd          66
# movers         48
# biggest        46
# upgrades       39
# downgrades     38
# Name: Bill Haddad, dtype: int64
#
# Top words for Bill Stoller:
# reit        403
# reits       139
# center      109
# data         97
# realty       79
# real         74
# estate       72
# earnings     69
# picks        65
# sector       59
# Name: Bill Stoller, dtype: int64
#
# Top words for Bit Whisperer:
# internet         1
# communication    1
# currency         1
# bitcoin          1
# 000              0
# optus            0
# or3o             0
# opxa             0
# opw              0
# opvido           0
# Name: Bit Whisperer, dtype: int64
#
# Top words for BlindReason:
# takedown      2
# insurance     2
# health        2
# ibd           2
# law           2
# musings       1
# nokia         1
# did           1
# successful    1
# broadens      1
# Name: BlindReason, dtype: int64
#
# Top words for BlueHill:
# dow          1
# falling      1
# portfolio    1
# stocks       1
# protect      1
# 000          0
# opw          0
# opvido       0
# opus         0
# opulan       0
# Name: BlueHill, dtype: int64
#
# Top words for Bo Belmer - Drivewealth:
# extinct     3
# 2017        3
# going       3
# brands      3
# big         1
# thing       1
# wearable    1
# tech        1
# opvido      0
# opus        0
# Name: Bo Belmer - Drivewealth, dtype: int64
#
# Top words for Bo Wang:
# oil           3
# cut           2
# asks          2
# india         2
# raises        2
# iran          2
# ahead         2
# imports       2
# maintains     2
# downgrades    1
# Name: Bo Wang, dtype: int64
#
# Top words for Bob Iaccino:
# trades      1
# joe         1
# campbell    1
# like        1
# manage      1
# optrex      0
# opuchase    0
# ora         0
# or3o        0
# opxa        0
# Name: Bob Iaccino, dtype: int64
#
# Top words for Bob Lang:
# high        5
# old         3
# mean        3
# volume      3
# earnings    3
# riding      3
# buy         3
# cheap       3
# horsemen    3
# does        3
# Name: Bob Lang, dtype: int64
#
# Top words for Bob White:
# pt            46
# reiterates    46
# morgan        12
# jefferies      9
# bofa           7
# deutsche       7
# bank           7
# jaffray        6
# lowers         5
# piper          5
# Name: Bob White, dtype: int64
#
# Top words for BobStewart:
# cdi            1
# ethics         1
# corporation    1
# 000            0
# opuchase       0
# ora            0
# or3o           0
# opxa           0
# opw            0
# opvido         0
# Name: BobStewart, dtype: int64
#
# Top words for BookingAlpha:
# update       6
# outlook      5
# market       5
# iwm          5
# vix          4
# nasdaq       4
# weekend      4
# tired        4
# moving       2
# unchanged    2
# Name: BookingAlpha, dtype: int64
#
# Top words for Brad Hammond:
# price       543
# check       542
# benzinga    541
# pro         541
# etf         452
# eps         310
# energy      297
# q1          287
# tech        280
# sales       279
# Name: Brad Hammond, dtype: int64
#
# Top words for Brad Slaughter:
# weekend      1
# trulieve     1
# pitches      1
# medipharm    1
# pure         1
# make         1
# global       1
# plus         1
# elevator     1
# opus         0
# Name: Brad Slaughter, dtype: int64
#
# Top words for Brad Thomas:
# healthcare    5
# basket        5
# build         5
# blue          5
# just          5
# complexity    3
# reits         3
# score         1
# knows         1
# store         1
# Name: Brad Thomas, dtype: int64
#
# Top words for Brandon Cunningham:
# eps         14
# q2          14
# revenues     9
# est          6
# earnings     6
# fall         3
# quarter      3
# expected     3
# previous     3
# bank         3
# Name: Brandon Cunningham, dtype: int64
#
# Top words for Brandon Pilzner:
# signal           63
# sector           48
# manufacturing    45
# industrial       39
# struggling       39
# market           35
# expected         34
# rise             34
# orders           33
# signals          33
# Name: Brandon Pilzner, dtype: int64
#
# Top words for Brandon Vlaar:
# day        2
# gas        2
# big        2
# natural    2
# optr       0
# optrex     0
# ora        0
# or3o       0
# opxa       0
# opw        0
# Name: Brandon Vlaar, dtype: int64
#
# Top words for Brantley Foster:
# td           10
# survey       10
# april        10
# declines     10
# imx          10
# stocks        8
# hurricane     8
# sandy         8
# mayans        2
# gun           2
# Name: Brantley Foster, dtype: int64
#
# Top words for BreakingFinanceNews:
# double      5
# digit       5
# losers      5
# winners     5
# 2013        5
# august      5
# 000         0
# opuchase    0
# or3o        0
# opxa        0
# Name: BreakingFinanceNews, dtype: int64
#
# Top words for Brent Douglas:
# apple        2
# companies    2
# tax          2
# policy       2
# embraced     2
# affect       2
# large        2
# like         2
# share        1
# stocks       1
# Name: Brent Douglas, dtype: int64
#
# Top words for Brent Slava:
# earnest     32
# earnings    32
# season      32
# starts      32
# week        32
# tickers     26
# benzinga    26
# look        26
# 2019        22
# 10          19
# Name: Brent Slava, dtype: int64
#
# Top words for Bret Jensen:
# undervalued    2
# tech           2
# 000            0
# optum          0
# opw            0
# opvido         0
# opus           0
# opulan         0
# opuchase       0
# optus          0
# Name: Bret Jensen, dtype: int64
#
# Top words for Brett Callwood:
# earnings    22
# sees        19
# quarter     19
# stock       18
# deal        16
# shares      16
# million     16
# stocks      16
# sales       16
# fall        15
# Name: Brett Callwood, dtype: int64
#
# Top words for Brett Hershman:
# stocks      1264
# session     1263
# moving      1255
# earnings     142
# says         105
# 10            98
# shares        79
# q2            75
# q3            73
# beat          71
# Name: Brett Hershman, dtype: int64
#
# Top words for Brett Phillips:
# work        5
# 10          5
# best        5
# cities      5
# cfa         5
# opuchase    0
# ora         0
# or3o        0
# opxa        0
# opw         0
# Name: Brett Phillips, dtype: int64
#
# Top words for Brett's Stock Market Pulse:
# problem     1
# volume      1
# holds       1
# 000         0
# optum       0
# opw         0
# opvido      0
# opus        0
# opulan      0
# opuchase    0
# Name: Brett's Stock Market Pulse, dtype: int64
#
# Top words for Brian Dolan:
# dolan       1
# 000         0
# optum       0
# opw         0
# opvido      0
# opus        0
# opulan      0
# opuchase    0
# optus       0
# optune      0
# Name: Brian Dolan, dtype: int64
#
# Top words for Brian Kline:
# equity          2
# home            2
# improvements    2
# build           2
# 000             0
# optus           0
# ora             0
# or3o            0
# opxa            0
# opw             0
# Name: Brian Kline, dtype: int64
#
# Top words for Brian Sozzi:
# wall      22
# deal      19
# real      17
# things     8
# really     8
# ugly       8
# june       8
# sales      8
# retail     8
# street     5
# Name: Brian Sozzi, dtype: int64
#
# Top words for BrianSozzi:
# decoding    8
# wall        6
# express     2
# market      2
# stock       2
# really      2
# scripts     2
# street      2
# joke        2
# medco       2
# Name: BrianSozzi, dtype: int64
#
# Top words for Brianna Valleskey:
# analysts     50
# wall         47
# street       47
# 25           47
# 10           16
# companies    15
# stocks       15
# corporate    13
# brands       13
# market       10
# Name: Brianna Valleskey, dtype: int64
#
# Top words for Bruce Kennedy:
# companies    44
# industry     20
# market       18
# auto         17
# sales        17
# retailers    17
# benefit      16
# stocks       14
# energy       14
# holiday      11
# Name: Bruce Kennedy, dtype: int64
#
# Top words for Bruce Krasting:
# funds        2
# red          1
# mm           1
# postal       1
# tim          1
# blame        1
# hedge        1
# america      1
# dumbest      1
# commodity    1
# Name: Bruce Krasting, dtype: int64
#
# Top words for Bruno del Ama:
# equal        1
# etfs         1
# commodity    1
# created      1
# opxa         0
# opw          0
# opvido       0
# opus         0
# opulan       0
# opuchase     0
# Name: Bruno del Ama, dtype: int64
#
# Top words for Bryan Finnigan:
# stocks       29
# shares       21
# estimates    15
# october      15
# place        14
# buy          14
# eps          14
# weeks        14
# despite      11
# remains      11
# Name: Bryan Finnigan, dtype: int64
#
# Top words for Bryan Stanford:
# acquisitions    4
# companies       4
# yahoo           4
# focus           4
# ad              4
# potential       4
# tech            4
# open            2
# calls           2
# times           1
# Name: Bryan Stanford, dtype: int64
#
# Top words for Bryce Matulonis:
# caused     34
# opening    34
# gap        34
# morning     3
# taronis     2
# icu         1
# sangamo     1
# shares      1
# bearish     1
# market      1
# Name: Bryce Matulonis, dtype: int64
#
# Top words for Bud Fox:
# earnings      149
# hours         128
# rating         97
# buy            96
# gainers        72
# today          59
# stocks         51
# estimates      48
# decliners      47
# reiterates     45
# Name: Bud Fox, dtype: int64
#
# Top words for Bull Market Bear:
# getting    1
# floor      1
# ground     1
# 000        0
# optune     0
# opxa       0
# opw        0
# opvido     0
# opus       0
# opulan     0
# Name: Bull Market Bear, dtype: int64
#
# Top words for BullBearTrades:
# srs        6
# class      5
# filed      5
# lawsuit    5
# action     5
# sun        2
# qid        2
# spy        2
# glenn      1
# update     1
# Name: BullBearTrades, dtype: int64
#
# Top words for BuyAndHoldPlus:
# ho          1
# hi          1
# optum360    0
# opxa        0
# opw         0
# opvido      0
# opus        0
# opulan      0
# opuchase    0
# optus       0
# Name: BuyAndHoldPlus, dtype: int64
#
# Top words for CEO World:
# stocks        1382
# ceoworld       856
# watch          530
# picks          350
# stock          271
# 10             216
# buy            215
# gas            151
# oil            134
# technology     106
# Name: CEO World, dtype: int64
#
# Top words for CME Group:
# wars        1
# price       1
# 000         0
# optum360    0
# opxa        0
# opw         0
# opvido      0
# opus        0
# opulan      0
# opuchase    0
# Name: CME Group, dtype: int64
#
# Top words for CPL:
# month       1
# problems    1
# nitrous     1
# billion     1
# exhausts    1
# cars        1
# smiling     1
# orana       0
# opts        0
# opus        0
# Name: CPL, dtype: int64
#
# Top words for Call Levels:
# big          1
# dominated    1
# themes       1
# trading      1
# optune       0
# opxa         0
# opw          0
# opvido       0
# opus         0
# opulan       0
# Name: Call Levels, dtype: int64
#
# Top words for CannabisFN:
# start         1
# valuations    1
# cannabisfn    1
# lower         1
# normalize     1
# stocks        1
# 000           0
# opxa          0
# opw           0
# opvido        0
# Name: CannabisFN, dtype: int64
#
# Top words for CapitalCube:
# earnings     81
# analysis     45
# energy       12
# betting      11
# duke          9
# growth        9
# stop          8
# shield        8
# procter       7
# strategic     7
# Name: CapitalCube, dtype: int64
#
# Top words for Carl Cachia:
# term         4
# catalysts    4
# foosteps     4
# set          4
# near         4
# follow       4
# actinium     4
# amid         4
# optronics    0
# opulan       0
# Name: Carl Cachia, dtype: int64
#
# Top words for CarpeDiem:
# index       27
# economic    20
# leading     16
# staffing    13
# asa         13
# high        12
# new         10
# markets      9
# reaches      8
# recovery     8
# Name: CarpeDiem, dtype: int64
#
# Top words for Catherine Ross:
# adds         2
# content      2
# tesla        2
# elon         2
# musk         2
# customers    2
# chinese      2
# video        2
# futures      1
# preorders    1
# Name: Catherine Ross, dtype: int64
#
# Top words for Cathy Ryan:
# oil           8
# bond          5
# watch         5
# year          5
# domestic      5
# deutsche      3
# pioneer       3
# anadarko      3
# integrated    3
# downgraded    3
# Name: Cathy Ryan, dtype: int64
#
# Top words for Chaim Siegel:
# month         2
# 12            2
# integrated    2
# 50            2
# stock         2
# percent       2
# earnings      2
# maxim         2
# upside        2
# reports       2
# Name: Chaim Siegel, dtype: int64
#
# Top words for Charles Enser:
# ipo       253
# week      115
# ipos       81
# april      44
# march      34
# review     26
# brings     19
# busy       17
# june       17
# 2014       16
# Name: Charles Enser, dtype: int64
#
# Top words for Charles Gross:
# vs          16641
# option      15728
# says         8220
# ask          7598
# earnings     7596
# chatter      7148
# shares       6793
# traded       6774
# calls        6654
# ref          5947
# Name: Charles Gross, dtype: int64
#
# Top words for Charles Hugh Smith:
# stocks        4
# noise         2
# scrape        2
# away          2
# strategy      1
# widen         1
# buy           1
# pretend       1
# bullish       1
# contrarian    1
# Name: Charles Hugh Smith, dtype: int64
#
# Top words for Charles Lewis Sizemore CFA:
# sizemore      22
# capital       20
# investors     18
# quarter       16
# emerging      15
# letter        14
# 2010          10
# management    10
# markets        9
# 3rd            9
# Name: Charles Lewis Sizemore CFA, dtype: int64
#
# Top words for Charley Blaine:
# stocks     90
# market     71
# 500        55
# october    36
# wrap       36
# new        33
# like       27
# fed        23
# highs      22
# 2013       20
# Name: Charley Blaine, dtype: int64
#
# Top words for Charlie Goodman:
# locks          1
# production     1
# opportunity    1
# offering       1
# deal           1
# soltera        1
# revenues       1
# mining         1
# opulan         0
# optosweden     0
# Name: Charlie Goodman, dtype: int64
#
# Top words for Charlie Strout:
# reports      1
# barnes       1
# spotlight    1
# flies        1
# death        1
# digital      1
# drops        1
# deere        1
# silently     1
# gap          1
# Name: Charlie Strout, dtype: int64
#
# Top words for Chart-Caster:
# double        2
# new           2
# sell          2
# time          2
# free          2
# trial         2
# brand         2
# years         1
# delivers      1
# astounding    1
# Name: Chart-Caster, dtype: int64
#
# Top words for Chemistfrog:
# multiple         6
# steadily         5
# increases        5
# intellectual     5
# property         5
# immunotherapy    3
# mean             3
# antigen          3
# marketing        3
# frontrunner      3
# Name: Chemistfrog, dtype: int64
#
# Top words for China Alternative Investments Group:
# undervalued    3
# buy            3
# investments    3
# stock          3
# strong         3
# alternative    3
# optum          0
# opw            0
# opvido         0
# opus           0
# Name: China Alternative Investments Group, dtype: int64
#
# Top words for Chip Ludgate:
# solid         1
# chesapeake    1
# small         1
# oil           1
# ops           1
# funding       1
# announced     1
# rackspace     1
# gap           1
# offset        1
# Name: Chip Ludgate, dtype: int64
#
# Top words for Chris Carey - Sharesleuth:
# mara          5
# cool          5
# chain         3
# daisy         3
# big           3
# south         2
# case          2
# florida       2
# additional    2
# group         2
# Name: Chris Carey - Sharesleuth, dtype: int64
#
# Top words for Chris Ciaccia:
# today       4
# higher      4
# sharply     4
# metals      4
# fed         3
# inflate     3
# consider    2
# squeezes    2
# short       2
# optum       0
# Name: Chris Ciaccia, dtype: int64
#
# Top words for Chris Dier-Scalise:
# vetr           192
# wetrader       165
# earnings       157
# competition    140
# round          105
# imx             85
# buy             82
# investors       79
# stocks          77
# week            73
# Name: Chris Dier-Scalise, dtype: int64
#
# Top words for Chris Freeman:
# soar          1
# cuts          1
# announcing    1
# job           1
# merck         1
# shares        1
# optus         0
# opxa          0
# opw           0
# opvido        0
# Name: Chris Freeman, dtype: int64
#
# Top words for Chris Fromhertz:
# nfib         5
# optimism     5
# companies    5
# small        5
# benefit      5
# business     5
# 000          0
# or3o         0
# opxa         0
# opw          0
# Name: Chris Fromhertz, dtype: int64
#
# Top words for Chris Katje:
# oprah          2
# save           2
# million        2
# viewers        2
# griffin        1
# robert         1
# endorsement    1
# rookie         1
# strategy       1
# andrew         1
# Name: Chris Katje, dtype: int64
#
# Top words for Chris Kimble:
# support     5
# junk        4
# just        4
# bonds       4
# testing     4
# channels    3
# tested      3
# stocks      3
# global      3
# broke       2
# Name: Chris Kimble, dtype: int64
#
# Top words for Chris Poley:
# senior       18
# earnings     16
# care         12
# buys         12
# health       12
# investors    10
# flock         9
# living        9
# stocks        9
# sunrise       9
# Name: Chris Poley, dtype: int64
#
# Top words for Chris Vermeulen:
# key              2
# breaking         2
# sectors          2
# possible         2
# gold             1
# volatility       1
# traded           1
# funds            1
# trade            1
# understanding    1
# Name: Chris Vermeulen, dtype: int64
#
# Top words for Chris Versace:
# calendars     16
# catalysts     16
# ecosystem      9
# mobile         9
# patents        8
# litigation     8
# paying         7
# storm          7
# port           7
# dividend       7
# Name: Chris Versace, dtype: int64
#
# Top words for Christian Fromhertz:
# restoration    1
# retailer       1
# 000            0
# oracel         0
# ora            0
# or3o           0
# opxa           0
# opw            0
# opvido         0
# opus           0
# Name: Christian Fromhertz, dtype: int64
#
# Top words for Christian Tharp CMT:
# biotech            91
# stocks             51
# stock              45
# star               30
# pharmaceuticals    15
# market             13
# biogen              9
# 2014                9
# worth               9
# idec                9
# Name: Christian Tharp CMT, dtype: int64
#
# Top words for Christina Jackson:
# eps          72
# sales        68
# reports      51
# q4           44
# sees         26
# 2018         14
# announces    11
# shares        9
# q1            9
# group         8
# Name: Christina Jackson, dtype: int64
#
# Top words for Christopher Brecher:
# options      72
# alert        32
# petroleum     6
# activity      4
# select        4
# spdr          4
# sector        4
# unusual       4
# whiting       4
# financial     4
# Name: Christopher Brecher, dtype: int64
#
# Top words for Christopher Dier-Scalise:
# etfs          14
# leveraged     14
# volatility    12
# earnings      12
# affect        12
# season        12
# td             9
# low            8
# continued      8
# ameritrade     8
# Name: Christopher Dier-Scalise, dtype: int64
#
# Top words for Christopher Sappo:
# volatility    8
# securities    8
# lending       8
# index         7
# look          4
# viewing       2
# powered       2
# putting       2
# markets       2
# tidal         2
# Name: Christopher Sappo, dtype: int64
#
# Top words for Chuck Carnevale:
# dividend       40
# stocks         32
# growth         26
# total          15
# return         15
# undervalued    15
# price          11
# utility        10
# volatility      9
# higher          9
# Name: Chuck Carnevale, dtype: int64
#
# Top words for Chuck Miller:
# warren         4
# buffett        4
# news           2
# shares         2
# continues      2
# energy         1
# abercrombe     1
# equinix        1
# acqusitions    1
# spike          1
# Name: Chuck Miller, dtype: int64
#
# Top words for Chuck Stone:
# ends          2
# axes          2
# plans         2
# allscripts    2
# sell          2
# 000           0
# optum360      0
# opvido        0
# opus          0
# opulan        0
# Name: Chuck Stone, dtype: int64
#
# Top words for Claire Kenney:
# stocks         8
# unanimously    5
# known          5
# fewer          5
# sentiment      5
# black          5
# early          5
# retailers      5
# opened         5
# means          5
# Name: Claire Kenney, dtype: int64
#
# Top words for Clay Wyatt:
# earnings      58
# guidance      49
# quarter       19
# surges        17
# posts         16
# tanks         16
# successful    15
# weak          15
# high          14
# eps           13
# Name: Clay Wyatt, dtype: int64
#
# Top words for Cliff Wachtel:
# market     20
# forex      12
# stocks      9
# outlook     9
# global      8
# gmt         8
# sept        8
# brief       8
# 7th         6
# week        6
# Name: Cliff Wachtel, dtype: int64
#
# Top words for ClosingBell:
# 2016        15
# pick        15
# traders     15
# stocks      15
# favorite    15
# biotech     15
# optus        0
# or3o         0
# opxa         0
# opw          0
# Name: ClosingBell, dtype: int64
#
# Top words for Connor Yee:
# report        2
# earnings      2
# mobileiron    1
# time          1
# america       1
# wunderlich    1
# maintains     1
# wells         1
# reaction      1
# strong        1
# Name: Connor Yee, dtype: int64
#
# Top words for Cooper Ziecik:
# earnings     9
# initiates    8
# june         6
# growth       6
# 2013         6
# buy          5
# pt           5
# bank         4
# raises       3
# lowers       3
# Name: Cooper Ziecik, dtype: int64
#
# Top words for Cory Mitchell:
# intervention    2
# big             2
# million         1
# loses           1
# rogue           1
# 1929            1
# depot           1
# gained          1
# pattern         1
# point           1
# Name: Cory Mitchell, dtype: int64
#
# Top words for Courtney Myers:
# market       9
# tourism      7
# boom         7
# travel       7
# continues    7
# stocks       7
# investing    7
# financial    3
# rates        2
# stock        2
# Name: Courtney Myers, dtype: int64
#
# Top words for Covestor:
# market       88
# stocks       59
# model        45
# portfolio    43
# big          34
# facebook     31
# zillow       31
# trumps       31
# 2012         29
# rally        29
# Name: Covestor, dtype: int64
#
# Top words for Craig Adeyanju:
# companies    13
# food          4
# aca           4
# energy        4
# care          4
# minimize      4
# impact        4
# projects      4
# services      4
# act           3
# Name: Craig Adeyanju, dtype: int64
#
# Top words for Craig Jones:
# money       4969
# etf         4183
# fast        4031
# picks       4000
# cramer      3676
# jim         2828
# thoughts    1036
# shares      1014
# opinion      900
# gives        891
# Name: Craig Jones, dtype: int64
#
# Top words for Credibly:
# small             5
# victim            3
# business          3
# let               3
# cybercriminals    3
# fall              3
# culture           2
# critical          2
# line              2
# company           2
# Name: Credibly, dtype: int64
#
# Top words for Crowder Options:
# ahead         1
# small         1
# trade         1
# potential     1
# extreme       1
# caps          1
# overbought    1
# hit           1
# optrex        0
# opw           0
# ...
#
# Top words for cyrus21:
# novagant    1
# eye         1
# 000         0
# optum360    0
# opxa        0
# opw         0
# opvido      0
# opus        0
# opulan      0
# opuchase    0
# Name: cyrus21, dtype: int64
#
# Top words for davidfabian:
# currency       4
# japan          4
# risk           4
# etf            4
# hedge          4
# let            2
# edge           2
# performance    2
# anxiety        2
# push           2
# Name: davidfabian, dtype: int64
#
# Top words for dbratzke:
# likes       1
# analyst     1
# ubs         1
# tobacco     1
# stocks      1
# optum360    0
# opw         0
# opvido      0
# opus        0
# opulan      0
# Name: dbratzke, dtype: int64
#
# Top words for dhiraj.surapaneni@benzinga.com:
# device        1
# higher        1
# growth        1
# upgrades      1
# confidence    1
# integrated    1
# technology    1
# bofa          1
# opulan        0
# ora           0
# Name: dhiraj.surapaneni@benzinga.com, dtype: int64
#
# Top words for dimarco:
# copper    9
# merkel    8
# says      8
# wheat     6
# cbot      5
# saying    5
# corn      5
# demand    4
# gains     4
# rises     4
# Name: dimarco, dtype: int64
#
# Top words for douglascarey:
# dividend     6
# growth       3
# great        3
# payers       3
# inflation    2
# beat         2
# optus        0
# opxa         0
# opw          0
# opvido       0
# Name: douglascarey, dtype: int64
#
# Top words for elliottwave:
# preparing    1
# bounce       1
# stocks       1
# energy       1
# optune       0
# opxa         0
# opw          0
# opvido       0
# opus         0
# opulan       0
# Name: elliottwave, dtype: int64
#
# Top words for fnmedia:
# gaming      6
# mobile      6
# growth      3
# lead        3
# plans       3
# online      3
# news        3
# reaching    3
# business    3
# apps        3
# Name: fnmedia, dtype: int64
#
# Top words for gary:
# jan        3
# options    2
# sold       2
# paper      2
# gdx        1
# buys       1
# dec        1
# 52p        1
# bough      1
# 63c        1
# Name: gary, dtype: int64
#
# Top words for giovannimola:
# electric    1
# stock       1
# great       1
# hawaiian    1
# traders     1
# opton       0
# optum360    0
# opw         0
# opvido      0
# opus        0
# Name: giovannimola, dtype: int64
#
# Top words for gmaxxx:
# ikarus      1
# air         1
# quo         1
# group       1
# rising      1
# alaska      1
# optum360    0
# opw         0
# opvido      0
# opus        0
# Name: gmaxxx, dtype: int64
#
# Top words for hawaiiforex:
# levels      2
# dinapoli    2
# video       1
# 6th         1
# week        1
# sep         1
# outlook     1
# gmt         1
# oil         1
# 23          1
# Name: hawaiiforex, dtype: int64
#
# Top words for inthemoneystocks:
# stocks     554
# market     191
# gold       154
# markets    124
# stock      117
# dollar     107
# oil         92
# rally       70
# miners      69
# early       69
# Name: inthemoneystocks, dtype: int64
#
# Top words for investingdaily:
# stocks       24
# gas          16
# growth       13
# utility      13
# deepwater    10
# mlp          10
# right         9
# reasons       9
# bargain       9
# making        8
# Name: investingdaily, dtype: int64
#
# Top words for investmentcontrarians:
# stocks         24
# retail         20
# market         17
# investors      13
# favorite       12
# making         11
# opportunity    10
# investing       9
# economic        9
# oil             9
# Name: investmentcontrarians, dtype: int64
#
# Top words for jacobwolinsky:
# value              3
# cap                2
# retailer           2
# bebe               2
# small              2
# feinberg           2
# capital            1
# dirt               1
# differentiation    1
# strong             1
# Name: jacobwolinsky, dtype: int64
#
# Top words for janaviktoria:
# estate            1
# survey            1
# real              1
# shows             1
# strong            1
# sustainability    1
# improvement       1
# industry          1
# optosweden        0
# optus             0
# Name: janaviktoria, dtype: int64
#
# Top words for javierhasseandericterbush@benzinga.com:
# cannabis      1
# canada        1
# secret        1
# best          1
# performing    1
# sauce         1
# etf           1
# 000           0
# opus          0
# oracale       0
# Name: javierhasseandericterbush@benzinga.com, dtype: int64
#
# Top words for jennifer25anthony@gmail.com:
# price         2
# raises        2
# target        2
# maintains     2
# macquarie     1
# outperform    1
# procter       1
# deutsche      1
# bank          1
# buy           1
# Name: jennifer25anthony@gmail.com, dtype: int64
#
# Top words for joreal2479:
# financial    1
# money        1
# falling      1
# sectors      1
# make         1
# opxa         0
# opw          0
# opvido       0
# opus         0
# opulan       0
# Name: joreal2479, dtype: int64
#
# Top words for josieclarks:
# career        1
# ocean         1
# advances      1
# powerbuoy     1
# agreement     1
# worth         1
# surging       1
# power         1
# technology    1
# stock         1
# Name: josieclarks, dtype: int64
#
# Top words for jsq_njoptions:
# watch     17
# list      17
# buy        9
# 000        0
# optus      0
# or3o       0
# opxa       0
# opw        0
# opvido     0
# opus       0
# Name: jsq_njoptions, dtype: int64
#
# Top words for karlalant:
# tech          2
# change        1
# north         1
# investment    1
# moves         1
# local         1
# outlook       1
# optune        0
# opxa          0
# opw           0
# Name: karlalant, dtype: int64
#
# Top words for karnacua2:
# shares       3
# surged       2
# initiated    1
# results      1
# q3           1
# track        1
# geron        1
# callidus     1
# previous     1
# fy2013       1
# Name: karnacua2, dtype: int64
#
# Top words for kiana@investdiva.com:
# ameritrade          1
# alibaba             1
# td                  1
# drop                1
# cryptocurrencies    1
# partnership         1
# despite             1
# gains               1
# new                 1
# investment          1
# Name: kiana@investdiva.com, dtype: int64
#
# Top words for konraad:
# revolution     3
# bet            3
# battery        3
# ways           3
# positioning    2
# worth          2
# look           2
# taking         2
# biotech        2
# stocks         2
# Name: konraad, dtype: int64
#
# Top words for krishnabagra:
# makes            4
# staffing         4
# market           4
# consolidation    4
# play             4
# sense            4
# wave             4
# dna              2
# precious         2
# meets            2
# Name: krishnabagra, dtype: int64
#
# Top words for lbjacobi:
# eps         95
# sales       81
# vs          63
# sees        43
# shares      38
# q1          32
# est         31
# fy2018      31
# beats       31
# estimate    30
# Name: lbjacobi, dtype: int64
#
# Top words for luke@benzinga.com:
# trading        1990
# shares         1833
# companies      1164
# stocks         1025
# lower           996
# coronavirus     899
# sales           891
# eps             865
# 2018            824
# global          821
# Name: luke@benzinga.com, dtype: int64
#
# Top words for marketHEIST:
# debt         2
# trade        2
# ceiling      2
# just         1
# multiple     1
# investors    1
# review       1
# numbers      1
# levels       1
# technical    1
# Name: marketHEIST, dtype: int64
#
# Top words for marketresearch:
# report               2
# market               2
# marketing            1
# pharmaceutical       1
# diabetes             1
# media                1
# effective            1
# strategies           1
# marketsandmarkets    1
# united               1
# Name: marketresearch, dtype: int64
#
# Top words for mary lou:
# follow         4
# miners         4
# suit           4
# gold           4
# etfs           4
# sequenom       3
# friday         2
# black          2
# speculative    2
# retailers      2
# Name: mary lou, dtype: int64
#
# Top words for mattzinga:
# annuity        2
# investments    2
# right          2
# optune         0
# or3o           0
# opxa           0
# opw            0
# opvido         0
# opus           0
# opulan         0
# Name: mattzinga, dtype: int64
#
# Top words for mdmconsult:
# intel             4
# expands           4
# pharmaceutical    4
# omnichannel       4
# mobile            3
# walmart           3
# future            2
# tablet            2
# market            2
# stock             2
# Name: mdmconsult, dtype: int64
#
# Top words for michaelfabian:
# alternative      4
# international    2
# interesting      2
# dividend         2
# hedge            2
# etfs             2
# inflation        2
# boring           2
# optum            0
# ora              0
# Name: michaelfabian, dtype: int64
#
# Top words for milesyoung:
# coolest      1
# tech         1
# companies    1
# canadian     1
# 000          0
# optune       0
# opxa         0
# opw          0
# opvido       0
# opus         0
# Name: milesyoung, dtype: int64
#
# Top words for mjintertrader:
# crumble        1
# perceptions    1
# amid           1
# bubble         1
# stocks         1
# technology     1
# optus          0
# opxa           0
# opw            0
# opvido         0
# Name: mjintertrader, dtype: int64
#
# Top words for moneytips:
# card       10
# credit     10
# hit         9
# high        7
# cards       4
# web         3
# dark        3
# worth       3
# virtual     2
# half        2
# Name: moneytips, dtype: int64
#
# Top words for msp2nyc:
# airlines      4
# netjets       2
# jet           2
# nearly        2
# lay           2
# fees          2
# 500           2
# operator      2
# close         2
# additional    2
# Name: msp2nyc, dtype: int64
#
# Top words for muathe:
# etf           1
# money         1
# research      1
# china         1
# regardless    1
# lost          1
# correct       1
# optum         0
# opts          0
# oracale       0
# Name: muathe, dtype: int64
#
# Top words for newsdesk+benzingastaffwriter3@benzinga.com:
# report          6
# closing         3
# earnings        3
# q3              3
# et              2
# issues          2
# historically    2
# chipotle        1
# group           1
# media           1
# Name: newsdesk+benzingastaffwriter3@benzinga.com, dtype: int64
#
# Top words for official@stockmetrix.net:
# time        1
# race        1
# opts        0
# opw         0
# opvido      0
# opus        0
# opulan      0
# opuchase    0
# optus       0
# optune      0
# Name: official@stockmetrix.net, dtype: int64
#
# Top words for olatujer:
# thursday     1
# proposed     1
# union        1
# singapore    1
# billion      1
# lower        1
# bank         1
# inject       1
# noon         1
# shares       1
# Name: olatujer, dtype: int64
#
# Top words for optionsXpress:
# market        638
# earnings      125
# support        77
# volatility     77
# resistance     76
# sectors        69
# waiting        69
# data           68
# rally          66
# watch          65
# Name: optionsXpress, dtype: int64
#
# Top words for optionsXpress_:
# rallies     2
# cocoa       1
# rates       1
# ecb         1
# stuck       1
# grind       1
# continue    1
# prices      1
# bull        1
# chinese     1
# Name: optionsXpress_, dtype: int64
#
# Top words for pagetraffic:
# pagetraffic    1
# new            1
# opens          1
# company        1
# expands        1
# seo            1
# chicago        1
# office         1
# optune         0
# opw            0
# Name: pagetraffic, dtype: int64
#
# Top words for parlorfix:
# stocks     14
# soup        6
# food        6
# tech        5
# lose        4
# results     4
# mixed       4
# heat        3
# yorkers     3
# love        3
# Name: parlorfix, dtype: int64
#
# Top words for parvgoel:
# ugly        2
# retail      2
# 000         0
# ora         0
# opxa        0
# opw         0
# opvido      0
# opus        0
# opulan      0
# opuchase    0
# Name: parvgoel, dtype: int64
#
# Top words for pconfidential:
# stock       16
# market      15
# high        10
# new          8
# stocks       7
# metals       6
# numbers      6
# dogs         6
# year         6
# precious     6
# Name: pconfidential, dtype: int64
#
# Top words for phil:
# new          1
# time         1
# opton        0
# optopatch    0
# or3o         0
# opxa         0
# opw          0
# opvido       0
# opus         0
# opulan       0
# Name: phil, dtype: int64
#
# Top words for proconfidential:
# chinese       2
# ipos          2
# insatiable    2
# appetite      2
# growth        1
# prices        1
# incredible    1
# production    1
# helping       1
# oil           1
# Name: proconfidential, dtype: int64
#
# Top words for prudentinvestor:
# gold          7
# bank          5
# sales         4
# dollar        4
# central       3
# simulation    3
# new           3
# fed           3
# greek         3
# heads         2
# Name: prudentinvestor, dtype: int64
#
# Top words for richa28dhand@gmail.com:
# price        17
# maintains    17
# target       17
# raises       13
# stanley       8
# morgan        8
# buy           5
# common        4
# lowers        4
# deutsche      3
# Name: richa28dhand@gmail.com, dtype: int64
#
# Top words for riddock57:
# biotech          4
# international    4
# cancer           4
# trial            4
# brain            4
# positive         4
# oncolytics       4
# deal             4
# results          4
# ophthotech       4
# Name: riddock57, dtype: int64
#
# Top words for seekinGold:
# gold         4
# oil          3
# forecasts    3
# rising       3
# rogers       3
# stocks       1
# 000          0
# optus        0
# opxa         0
# opw          0
# Name: seekinGold, dtype: int64
#
# Top words for shivdeep@benzinga.com:
# discloses      2
# time           2
# revenue        2
# google         2
# youtube        2
# controversy    1
# security       1
# concerns       1
# facebook       1
# political      1
# Name: shivdeep@benzinga.com, dtype: int64
#
# Top words for strichie:
# hold          36
# buy           32
# likes         15
# sell          14
# downgrades    14
# strong        10
# says           9
# upgrades       8
# earnings       8
# raises         8
# Name: strichie, dtype: int64
#
# Top words for summerellie:
# high            2
# trend           2
# protein         2
# watch           2
# new             2
# products        1
# buy             1
# premium         1
# optimizaiton    0
# optune          0
# Name: summerellie, dtype: int64
#
# Top words for summers s:
# watch        4
# 15           4
# companies    4
# big          4
# data         4
# opvido       0
# oracel       0
# oracale      0
# ora          0
# optricon     0
# Name: summers s, dtype: int64
#
# Top words for superman:
# stock      16
# week       11
# skbi        9
# mrm         9
# gainer      9
# china       9
# chinese     8
# skystar     8
# new         8
# float       7
# Name: superman, dtype: int64
#
# Top words for swenstock:
# basic       1
# stocks      1
# material    1
# chinese     1
# soar        1
# 000         0
# optune      0
# opw         0
# opvido      0
# opus        0
# Name: swenstock, dtype: int64
#
# Top words for themoneygardener:
# dividend     11
# pays          7
# gamble        7
# procter       7
# stocks        4
# 2010          3
# consumer      3
# dividends     3
# raise         3
# bullish       3
# Name: themoneygardener, dtype: int64
#
# Top words for theoxengroup:
# watch        3
# companies    3
# november     3
# dollar       2
# rebound      2
# october      2
# history      2
# shows        2
# 000          0
# opw          0
# Name: theoxengroup, dtype: int64
#
# Top words for tradermark:
# fund           408
# week           233
# year           219
# positions      216
# weekly         200
# changes        200
# performance    176
# period         175
# 2010           162
# stocks          84
# Name: tradermark, dtype: int64
#
# Top words for tradingwithwaves:
# rise        5
# stocks      3
# caution     3
# 500         3
# mortar      2
# bricks      2
# commerce    2
# 000         0
# opvido      0
# oracel      0
# Name: tradingwithwaves, dtype: int64
#
# Top words for tsmartin:
# plane       2
# kills       1
# airport     1
# crash       1
# crashes     1
# deadly      1
# civilian    1
# congo       1
# people      1
# 32          1
# Name: tsmartin, dtype: int64
#
# Top words for vic@forextraininggroup.com:
# netflix    1
# shows      1
# chart      1
# tumble     1
# primed     1
# 000        0
# optune     0
# opxa       0
# opw        0
# opvido     0
# Name: vic@forextraininggroup.com, dtype: int64
#
# Top words for vishwanath@benzinga.com:
# price         1829
# target        1827
# maintains     1707
# raises        1048
# lowers         759
# buy            503
# morgan         442
# stanley        409
# overweight     367
# neutral        235
# Name: vishwanath@benzinga.com, dtype: int64
#
# Top words for vivek.proactive@gmail.com:
# target        120
# price         120
# maintains     119
# raises         83
# buy            36
# lowers         36
# morgan         35
# stanley        33
# overweight     22
# neutral        16
# Name: vivek.proactive@gmail.com, dtype: int64
#
# Top words for wallstreet1928:
# 100         3
# daily       3
# 2009        3
# ftse        3
# analysis    2
# market      2
# level       1
# 30th        1
# 1700        1
# nasdaq      1
# Name: wallstreet1928, dtype: int64
#
# Top words for webmaster:
# pt           4678
# analyst      4570
# blog         4451
# maintains    3602
# vs           3380
# raises       2795
# reports      1878
# est          1818
# eps          1789
# revenues     1686
# Name: webmaster, dtype: int64

# %% [markdown]
# Identify Unique Domains from Email Addresses

# %%
import re


# Function to extract domain from email address
def extract_domain(email):
    match = re.search(r"@(\S+)", email)
    return match.group(1) if match else None


# Apply domain extraction
df["domain"] = df["publisher"].apply(extract_domain)

# Count the number of articles per domain
domain_counts = df["domain"].value_counts()

# Display the top domains
print(domain_counts)
# Out:
# domain
# benzinga.com              7937
# gmail.com                  139
# andyswan.com                 5
# investdiva.com               2
# tothetick.com                2
# eosdetroit.io                1
# forextraininggroup.com       1
# stockmetrix.net              1
# Name: count, dtype: int64
